# %%
import json

# 載入本地 hotpotqa JSON 檔
with open("hotpot_dev_distractor_v1.json", "r", encoding="utf-8") as f:
    dataset = json.load(f)

print(f"總共有 {len(dataset)} 筆資料")
# Out:
# 總共有 7405 筆資料

# %%
import sqlite3

conn = sqlite3.connect("Dataset/feverous_wikiv1.db")
cur = conn.cursor()

# 看看有什麼 Table
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cur.fetchall())

# 看看 wiki 表格的欄位
cur.execute("PRAGMA table_info(wiki);")
print(cur.fetchall())
# Out:
# [('wiki',)]
# [(0, 'id', '', 0, None, 1), (1, 'data', 'json', 0, None, 0)]

# %%
import sqlite3, json, pprint, textwrap

DB_PATH = "Dataset/feverous_wikiv1.db"   # ← 你的檔案路徑
conn = sqlite3.connect(DB_PATH)
cur  = conn.cursor()

# 看看前 5 個 page_id
for row in cur.execute("SELECT id FROM wiki LIMIT 5"):
    print(row[0])
# Out:
# ! (Cláudia Pascoal album)
# ! (The Dismemberment Plan album)
# ! (The Song Formerly Known As)
# ! (Trippie Redd album)

# %%
page_id = "Wolfgang_Niedecken"           # 任選一個
row = cur.execute("SELECT data FROM wiki WHERE id = ?", (page_id,)).fetchone()
page_json = json.loads(row[0])

# 印出所有 key（就是 element_id）
print(list(page_json.keys())[:20])       # 只列前 20 個看看
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 page_id = "Wolfgang_Niedecken"           # 任選一個
#       2 row = cur.execute("SELECT data FROM wiki WHERE id = ?", (page_id,)).fetchone()
# ----> 3 page_json = json.loads(row[0])
#       5 # 印出所有 key（就是 element_id）
#       6 print(list(page_json.keys())[:20])       # 只列前 20 個看看
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# 找所有包含 Wolfgang 的頁面
for (pid,) in cur.execute("SELECT id FROM wiki WHERE id LIKE 'Wolfgang %'"):
    print(pid)
# Out:
# Wolfgang (album)
# Wolfgang (band)
# Wolfgang (disambiguation)
# Wolfgang (wrestler)
# Wolfgang A. Tomé
# Wolfgang Abel and Marco Furlan
# Wolfgang Abendroth
# Wolfgang Ablinger-Sperrhacke
# Wolfgang Abraham
# Wolfgang Achtner
# Wolfgang Albers
# Wolfgang Albers (police president)
# Wolfgang Albers (politician)
# Wolfgang Alexander Thomas-San-Galli
# Wolfgang Altenburg
# Wolfgang Altmann
# Wolfgang Aly
# Wolfgang Amadeus Mozart
# Wolfgang Amadeus Mozart and Prague
# Wolfgang Amadeus Mozart and the Catholic Church
# Wolfgang Amadeus Mozart in popular culture
# Wolfgang Amadeus Phoenix
# Wolfgang April
# Wolfgang Assbrock
# Wolfgang Auderer
# Wolfgang Auhagen
# Wolfgang Bahro
# Wolfgang Baldus
# Wolfgang Bartels
# Wolfgang Bartels (politician, born 1903)
# Wolfgang Barthels
# Wolfgang Bauer
# Wolfgang Bauer (journalist)
# Wolfgang Bauer (physicist)
# Wolfgang Baumgart
# Wolfgang Baur
# Wolfgang Becker
# Wolfgang Becker (editor)
# Wolfgang Behringer
# Wolfgang Beltracchi
# Wolfgang Benkert
# Wolfgang Benz
# Wolfgang Bergold
# Wolfgang Bernhard
# Wolfgang Bernhard Fränkel
# Wolfgang Bibel
# Wolfgang Biedron
# Wolfgang Binding
# Wolfgang Birkner
# Wolfgang Birkner (rower)
# Wolfgang Blankenau
# Wolfgang Blenk
# Wolfgang Blochwitz
# Wolfgang Bochow
# Wolfgang Bodison
# Wolfgang Boettcher
# Wolfgang Boetticher
# Wolfgang Boos
# Wolfgang Borchert
# Wolfgang Borchert Theater
# Wolfgang Boss
# Wolfgang Böhm
# Wolfgang Böhme
# Wolfgang Böhmer
# Wolfgang Börnsen
# Wolfgang Bösl
# Wolfgang Bötsch
# Wolfgang Brandstetter
# Wolfgang Branoner
# Wolfgang Brase
# Wolfgang Brezinka
# Wolfgang Brinkmann
# Wolfgang Bubenik
# Wolfgang Buchleitner
# Wolfgang Burandt
# Wolfgang Burba
# Wolfgang Burmann
# Wolfgang Busch
# Wolfgang Buttress
# Wolfgang Büchner
# Wolfgang Büchner (journalist)
# Wolfgang Büttner
# Wolfgang Capito
# Wolfgang Carl Briegel
# Wolfgang Clemen
# Wolfgang Clement
# Wolfgang Condrus
# Wolfgang Cramer
# Wolfgang Dahmen
# Wolfgang Dandorfer
# Wolfgang Danne
# Wolfgang Dauner
# Wolfgang Dehnel
# Wolfgang Deml
# Wolfgang Demtröder
# Wolfgang Dessecker
# Wolfgang Dietrich
# Wolfgang Dietrich (businessman)
# Wolfgang Dietrich (footballer)
# Wolfgang Dietrich (political scientist)
# Wolfgang Diewerge
# Wolfgang Dimetrik
# Wolfgang Dittrich
# Wolfgang Doeblin
# Wolfgang Dorasil
# Wolfgang Dourado
# Wolfgang Döring
# Wolfgang Dramsch
# Wolfgang Drechsler
# Wolfgang Dremmler
# Wolfgang Drobetz
# Wolfgang Dubin
# Wolfgang Duncker
# Wolfgang Ebner
# Wolfgang Eder
# Wolfgang Egger
# Wolfgang Ehrl
# Wolfgang Eisenmenger
# Wolfgang Elsner
# Wolfgang End
# Wolfgang Ender
# Wolfgang Engel
# Wolfgang Engelmann
# Wolfgang Erdmann
# Wolfgang Erndl
# Wolfgang Ernst
# Wolfgang Ernst (media theorist)
# Wolfgang Ernst I of Isenburg-Büdingen-Birstein
# Wolfgang Euteneuer
# Wolfgang F. Danspeckgruber
# Wolfgang Faber
# Wolfgang Fahrian
# Wolfgang Falck
# Wolfgang Fasching
# Wolfgang Feiersinger
# Wolfgang Feneberg
# Wolfgang Fikentscher
# Wolfgang Finger
# Wolfgang Finkelnburg
# Wolfgang Fischer
# Wolfgang Fischer (athlete)
# Wolfgang Flöttl
# Wolfgang Foerster
# Wolfgang Fortner
# Wolfgang Frank
# Wolfgang Franke
# Wolfgang Franz
# Wolfgang Franz (mathematician)
# Wolfgang Franz von Kobell
# Wolfgang Frey
# Wolfgang Friedmann
# Wolfgang Friedrich Gess
# Wolfgang Fritsch
# Wolfgang Fuchs
# Wolfgang Funkel
# Wolfgang Fürstner
# Wolfgang G. Schwanitz
# Wolfgang Gaede
# Wolfgang Gans zu Putlitz
# Wolfgang Gartner
# Wolfgang Gartner discography
# Wolfgang Gayer
# Wolfgang Gedeon
# Wolfgang Gentner
# Wolfgang George Frederick von Pfalz-Neuburg
# Wolfgang Georgsdorf
# Wolfgang Gerhardt
# Wolfgang Gerz
# Wolfgang Gewalt
# Wolfgang Giegerich
# Wolfgang Girardi
# Wolfgang Glänzel
# Wolfgang Glock
# Wolfgang Glock (rower)
# Wolfgang Glück
# Wolfgang Gockel
# Wolfgang Goedecke
# Wolfgang Goler
# Wolfgang Gödicke
# Wolfgang Gönnenwein
# Wolfgang Götze
# Wolfgang Grams
# Wolfgang Graßl
# Wolfgang Grobe
# Wolfgang Grodd
# Wolfgang Groß
# Wolfgang Gröbner
# Wolfgang Grönebaum
# Wolfgang Gruber
# Wolfgang Grzyb
# Wolfgang Gunkel
# Wolfgang Güldenpfennig
# Wolfgang Güllich
# Wolfgang Güttler
# Wolfgang H. Berger
# Wolfgang H. Scholz
# Wolfgang Haack
# Wolfgang Haas
# Wolfgang Haase
# Wolfgang Haber
# Wolfgang Hackbusch
# Wolfgang Haffner
# Wolfgang Hahn
# Wolfgang Haken
# Wolfgang Hamberger
# Wolfgang Hanisch
# Wolfgang Harich
# Wolfgang Hartl
# Wolfgang Hasenfuss
# Wolfgang Haubrichs
# Wolfgang Händler
# Wolfgang Heidenfeld
# Wolfgang Heimlich
# Wolfgang Heine
# Wolfgang Heinrich Johannes Fuchs
# Wolfgang Heinz
# Wolfgang Heinz (actor)
# Wolfgang Heinz (criminologist)
# Wolfgang Heinz (politician)
# Wolfgang Helbich
# Wolfgang Helbig
# Wolfgang Hellmich
# Wolfgang Hellrigl
# Wolfgang Heribert von Dalberg
# Wolfgang Herold
# Wolfgang Herrmann
# Wolfgang Herz
# Wolfgang Hesl
# Wolfgang Heyda
# Wolfgang Hilbig
# Wolfgang Hildesheimer
# Wolfgang Hoffmann-Riem
# Wolfgang Hofmann
# Wolfgang Hohensee
# Wolfgang Hohlbein
# Wolfgang Hoppe
# Wolfgang Horak
# Wolfgang Hottenrott
# Wolfgang Hönig
# Wolfgang Huber
# Wolfgang Hunger
# Wolfgang Hutter
# Wolfgang Hübner
# Wolfgang Hünnekens
# Wolfgang I of Oettingen
# Wolfgang Ilgenfritz
# Wolfgang Ipolt
# Wolfgang Ischinger
# Wolfgang Iser
# Wolfgang J. Fuchs
# Wolfgang Jerat
# Wolfgang Jobst
# Wolfgang Joklik
# Wolfgang Joop
# Wolfgang Jöchl
# Wolfgang Jörg
# Wolfgang Junginger
# Wolfgang Jünger
# Wolfgang Jüttner
# Wolfgang K. H. Panofsky
# Wolfgang Kaiser
# Wolfgang Kaiser (KgU)
# Wolfgang Kaiser (physicist)
# Wolfgang Kaleck
# Wolfgang Kaniber
# Wolfgang Kapp
# Wolfgang Karl Weyrauch
# Wolfgang Kasack
# Wolfgang Katschner
# Wolfgang Katzheimer
# Wolfgang Kautek
# Wolfgang Kayser
# Wolfgang Kermer
# Wolfgang Ketter
# Wolfgang Ketterle
# Wolfgang Kieling
# Wolfgang Killing
# Wolfgang Kindl
# Wolfgang Kirchgässner
# Wolfgang Kittel
# Wolfgang Klapf
# Wolfgang Klapheck
# Wolfgang Klausewitz
# Wolfgang Kläsener
# Wolfgang Klein
# Wolfgang Klemperer
# Wolfgang Klingebiel
# Wolfgang Klinger
# Wolfgang Klocker
# Wolfgang Klotz
# Wolfgang Knabe
# Wolfgang Knaller
# Wolfgang Kneib
# Wolfgang Koch
# Wolfgang Koeppen
# Wolfgang Kohlhaase
# Wolfgang Kolmsee
# Wolfgang Konrad
# Wolfgang Köhler (pianist)
# Wolfgang Köpcke
# Wolfgang Köpfel
# Wolfgang Kramer
# Wolfgang Kraus
# Wolfgang Krause
# Wolfgang Krätschmer
# Wolfgang Kreissl-Dörfler
# Wolfgang Kreißig
# Wolfgang Kremer
# Wolfgang Krieger
# Wolfgang Kromp
# Wolfgang Kröger
# Wolfgang Krull
# Wolfgang Kubicki
# Wolfgang Kubin
# Wolfgang Kuck
# Wolfgang Kummer
# Wolfgang Kummer (bobsledder)
# Wolfgang Kummer (ice hockey)
# Wolfgang Kundt
# Wolfgang Kunkel
# Wolfgang Kusserow
# Wolfgang Kügler
# Wolfgang Lackerschmid
# Wolfgang Laib
# Wolfgang Lakenmacher
# Wolfgang Lange
# Wolfgang Lange (general)
# Wolfgang Langewiesche
# Wolfgang Langhoff
# Wolfgang Larrazábal
# Wolfgang Lauenstein
# Wolfgang Lazius
# Wolfgang Lehmacher
# Wolfgang Leinberer
# Wolfgang Leitner
# Wolfgang Lentz
# Wolfgang Lettl
# Wolfgang Leu
# Wolfgang Liebe
# Wolfgang Lindenhofer
# Wolfgang Linger
# Wolfgang Lippert
# Wolfgang Lippert (botanist)
# Wolfgang Lippert (pilot)
# Wolfgang Lischke
# Wolfgang Loitzl
# Wolfgang Loos
# Wolfgang Losack
# Wolfgang Lotz (art historian)
# Wolfgang Löscher
# Wolfgang Löwe
# Wolfgang Lubitz
# Wolfgang Ludwig Krafft
# Wolfgang Luthe
# Wolfgang Lutz
# Wolfgang Lück
# Wolfgang Lüderitz
# Wolfgang Lüderitz (composer)
# Wolfgang Lüderitz (pentathlete)
# Wolfgang Lüth
# Wolfgang M. Schmidt
# Wolfgang Maassen
# Wolfgang Maennig
# Wolfgang Mager
# Wolfgang Maibohm
# Wolfgang Maier
# Wolfgang Mair
# Wolfgang Makatsch
# Wolfgang Manz
# Wolfgang Marguerre
# Wolfgang Maria Bauer
# Wolfgang Martin Stroh
# Wolfgang Martini
# Wolfgang Mattheuer
# Wolfgang Matz
# Wolfgang Mayr
# Wolfgang Mayrhofer
# Wolfgang Männel
# Wolfgang Mechler
# Wolfgang Mejías
# Wolfgang Menge
# Wolfgang Meyer
# Wolfgang Michael
# Wolfgang Michel-Zaitsu
# Wolfgang Michels
# Wolfgang Mieder
# Wolfgang Mitterer
# Wolfgang Mommsen
# Wolfgang Moser
# Wolfgang Mulack
# Wolfgang Murnberger
# Wolfgang Musculus
# Wolfgang Muthspiel
# Wolfgang Müller
# Wolfgang Müller (actor)
# Wolfgang Müller (artist)
# Wolfgang Müller (equestrian)
# Wolfgang Müller (field hockey)
# Wolfgang Müller (skier)
# Wolfgang Müller (sprinter)
# Wolfgang Müller (weightlifter)
# Wolfgang Müller Kranefeldt
# Wolfgang Müller-Lauter
# Wolfgang Müller-Wiener
# Wolfgang Nastainczyk
# Wolfgang Nebel
# Wolfgang Neff
# Wolfgang Nešković
# Wolfgang Neumann
# Wolfgang Neuss
# Wolfgang Niedecken
# Wolfgang Niedrig
# Wolfgang Niersbach
# Wolfgang Nitschke
# Wolfgang Nonn
# Wolfgang Nordwig
# Wolfgang Novogratz
# Wolfgang Oehme
# Wolfgang Ott
# Wolfgang Overath
# Wolfgang Öxler
# Wolfgang P. Schleich
# Wolfgang Paalen
# Wolfgang Pagenstecher
# Wolfgang Partsch
# Wolfgang Pass
# Wolfgang Patsch
# Wolfgang Paul
# Wolfgang Paul (footballer)
# Wolfgang Pauli
# Wolfgang Pepper
# Wolfgang Perner
# Wolfgang Pesendorfer
# Wolfgang Peters
# Wolfgang Peters (canoeist)
# Wolfgang Petersen
# Wolfgang Petrick
# Wolfgang Petritsch
# Wolfgang Petry
# Wolfgang Pfeifer
# Wolfgang Pichler
# Wolfgang Pickert
# Wolfgang Pickl
# Wolfgang Pietzsch
# Wolfgang Pikal
# Wolfgang Plagge
# Wolfgang Plath
# Wolfgang Platzeck
# Wolfgang Plotka
# Wolfgang Plottke
# Wolfgang Popp
# Wolfgang Porsche
# Wolfgang Pree
# Wolfgang Preisendanz
# Wolfgang Printz
# Wolfgang Prinz
# Wolfgang Puck
# Wolfgang Puschnig
# Wolfgang Püchler
# Wolfgang R. Wasow
# Wolfgang Rademann
# Wolfgang Radmacher
# Wolfgang Rathert
# Wolfgang Ratke
# Wolfgang Rauchfuß
# Wolfgang Rausch
# Wolfgang Rautenberg
# Wolfgang Rehm
# Wolfgang Reichmann
# Wolfgang Reinhardt
# Wolfgang Reinhardt (athlete)
# Wolfgang Reinhardt (producer)
# Wolfgang Reinhold
# Wolfgang Reisinger
# Wolfgang Reitherman
# Wolfgang Rennert
# Wolfgang Richter
# Wolfgang Ries
# Wolfgang Riesinger
# Wolfgang Rihm
# Wolfgang Rindler
# Wolfgang Rolff
# Wolfgang Rosenthal
# Wolfgang Roth
# Wolfgang Rottmann
# Wolfgang Rösch
# Wolfgang Ruck
# Wolfgang Ruf
# Wolfgang Sandhowe
# Wolfgang Sandner
# Wolfgang Sartorius von Waltershausen
# Wolfgang Sawallisch
# Wolfgang Schadewaldt
# Wolfgang Schaper
# Wolfgang Scharf
# Wolfgang Schädler
# Wolfgang Schäfer
# Wolfgang Schäuble
# Wolfgang Scheffler
# Wolfgang Scheffler (historian)
# Wolfgang Scheffler (inventor)
# Wolfgang Scheidel
# Wolfgang Schenck
# Wolfgang Schilling
# Wolfgang Schilling (footballer, born 1955)
# Wolfgang Schilling (footballer, born 1957)
# Wolfgang Schillkowski
# Wolfgang Schirmacher
# Wolfgang Schluchter
# Wolfgang Schlumpf
# Wolfgang Schmelzer
# Wolfgang Schmidt
# Wolfgang Schmidt (disambiguation)
# Wolfgang Schmitt
# Wolfgang Schnarr
# Wolfgang Schneiderhan
# Wolfgang Schneiderhan (general)
# Wolfgang Schneiderhan (violinist)
# Wolfgang Schnur
# Wolfgang Schober
# Wolfgang Schomburg
# Wolfgang Schopf
# Wolfgang Schöne
# Wolfgang Schranz
# Wolfgang Schreyer
# Wolfgang Schröder
# Wolfgang Schulhoff
# Wolfgang Schulz
# Wolfgang Schumann (1887–1964)
# Wolfgang Schuster
# Wolfgang Schutzbar
# Wolfgang Schüler
# Wolfgang Schüssel
# Wolfgang Schwanitz
# Wolfgang Schwarz
# Wolfgang Schwarz (footballer)
# Wolfgang Schweickard
# Wolfgang Schwenke
# Wolfgang Schwenke (handballer)
# Wolfgang Schwerk
# Wolfgang Seel
# Wolfgang Seeliger
# Wolfgang Seguin
# Wolfgang Seidel
# Wolfgang Seifen
# Wolfgang Seiler
# Wolfgang Sidka
# Wolfgang Sieber
# Wolfgang Siemens
# Wolfgang Sievers
# Wolfgang Sigl
# Wolfgang Simon
# Wolfgang Smith
# Wolfgang Sofsky
# Wolfgang Solz
# Wolfgang Staehle
# Wolfgang Stahl
# Wolfgang Stammberger
# Wolfgang Stampfer
# Wolfgang Stark
# Wolfgang Staudinger
# Wolfgang Stechow
# Wolfgang Stefinger
# Wolfgang Steglich
# Wolfgang Stegmüller
# Wolfgang Steinbach
# Wolfgang Steinecke
# Wolfgang Steinert
# Wolfgang Steinitz
# Wolfgang Steinmayr
# Wolfgang Stock
# Wolfgang Stockmeier
# Wolfgang Stoerchle
# Wolfgang Stolper
# Wolfgang Stöckl
# Wolfgang Stöhr
# Wolfgang Straub
# Wolfgang Strauß
# Wolfgang Straßmann
# Wolfgang Streitenberger
# Wolfgang Strengmann-Kuhn
# Wolfgang Strobel
# Wolfgang Stroebe
# Wolfgang Strödter
# Wolfgang Stryi
# Wolfgang Stumph
# Wolfgang Stützel
# Wolfgang Suppan
# Wolfgang Suschitzky
# Wolfgang Sühnholz
# Wolfgang Templin
# Wolfgang Teuchert
# Wolfgang Thierse
# Wolfgang Thimmig
# Wolfgang Thomale
# Wolfgang Thonke
# Wolfgang Thüne
# Wolfgang Tiefensee
# Wolfgang Tillich
# Wolfgang Tillmans
# Wolfgang Tonne
# Wolfgang Trautwein
# Wolfgang Treu (cinematographer)
# Wolfgang Troßbach
# Wolfgang Trödler
# Wolfgang Tschirk
# Wolfgang Uhle
# Wolfgang Uhlmann
# Wolfgang Ullmann
# Wolfgang Ullrich
# Wolfgang Unger
# Wolfgang Unzicker
# Wolfgang Van Halen
# Wolfgang Victor Ruttkowski
# Wolfgang Viechtbauer
# Wolfgang Vogel
# Wolfgang Voigt
# Wolfgang Vondey
# Wolfgang Völz
# Wolfgang W. Wurster
# Wolfgang W.E. Samuel
# Wolfgang Wagner
# Wolfgang Wagner (disambiguation)
# Wolfgang Wagner (social psychologist)
# Wolfgang Wagner (swimmer)
# Wolfgang Wahl
# Wolfgang Wahlster
# Wolfgang Walter
# Wolfgang Walther
# Wolfgang Warnemünde
# Wolfgang Weber
# Wolfgang Weber (musicologist)
# Wolfgang Webner
# Wolfgang Wegener
# Wolfgang Wehrum
# Wolfgang Weichardt
# Wolfgang Weil
# Wolfgang Weimershaus
# Wolfgang Weingart
# Wolfgang Weisbrod-Weber
# Wolfgang Weise
# Wolfgang Wenzel
# Wolfgang Wenzel (sailor)
# Wolfgang Wenzel von Haffner
# Wolfgang Werlé and Manfred Lauber
# Wolfgang Wesemann
# Wolfgang Wessels
# Wolfgang Weyrauch
# Wolfgang Weyrauch Prize
# Wolfgang Wickler
# Wolfgang Wiegard
# Wolfgang Wiehle
# Wolfgang Wienand
# Wolfgang Wild
# Wolfgang Wilhelm
# Wolfgang Wilhelm (writer)
# Wolfgang William Romer
# Wolfgang Willrich
# Wolfgang Windgassen
# Wolfgang Winkler
# Wolfgang Winkler (actor)
# Wolfgang Wolf
# Wolfgang Wosolsobe
# Wolfgang Wüster
# Wolfgang Yorck von Wartenburg
# Wolfgang Zabba Lindner
# Wolfgang Zanger
# Wolfgang Zapf
# Wolfgang Zeidler
# Wolfgang Zeller
# Wolfgang Zelmer
# Wolfgang Zenker
# Wolfgang Ziebart
# Wolfgang Ziffer
# Wolfgang Zilzer
# Wolfgang Zimmerer
# Wolfgang Zinser
# Wolfgang Zuckermann
# Wolfgang Zuckschwerdt
# Wolfgang de Smet
# Wolfgang of Regensburg
# Wolfgang of the Palatinate
# Wolfgang von Chamier-Glisczinski
# Wolfgang von Dalberg
# Wolfgang von Graben
# Wolfgang von Gronau
# Wolfgang von Haffner
# Wolfgang von Kempelen
# Wolfgang von Kempelen's speaking machine
# Wolfgang von Kluge
# Wolfgang von Leyden
# Wolfgang von Schweinitz
# Wolfgang von Stetten
# Wolfgang von Trips
# Wolfgang von Wersin
# Wolfgang von der Nahmer

# %%
import re, sqlite3, json

DB_PATH = "Dataset/feverous_wikiv1.db"
conn    = sqlite3.connect(DB_PATH)
cur     = conn.cursor()

# ----------------  關鍵函式  ----------------
def split_content_id(cid: str):
    """
    解析 FEVEROUS content_id：
      Wolfgang_Niedecken_sentence_0   ->  (Wolfgang Niedecken, sentence_0)
      Wolfgang_Niedecken_cell_0_4_1   ->  (Wolfgang Niedecken, cell_0_4_1)
    """
    m = re.search(r'_(sentence|cell|header)_(.+)', cid)
    if not m:
        raise ValueError(f"Un-recognized content_id: {cid}")

    page_raw   = cid[:m.start()]                   # Wolfgang_Niedecken
    element_id = f"{m.group(1)}_{m.group(2)}"     # sentence_0 / cell_0_4_1 ...
    page_id    = page_raw.replace("_", " ")       # 換成空白 → DB 的主鍵

    return page_id, element_id


def fetch_content(cid: str, con=conn) -> str:
    # ① 拆 content_id
    page_id, element_id = split_content_id(cid)

    # ② 取整頁 JSON
    row = con.execute("SELECT data FROM wiki WHERE id = ?", (page_id,)).fetchone()
    if not row:
        return f"[找不到頁面 {page_id}]"

    data = json.loads(row[0])

    # ③ 先精確命中
    if element_id in data:
        return data[element_id]

    # ④ fallback：若是 cell → 回傳整格或第一句
    if element_id.startswith("cell_"):
        base = "_".join(element_id.split("_")[:3])          # cell_0_4
        for alt in (base, base + "_0"):                     # cell_0_4 → cell_0_4_0
            if alt in data:
                return data[alt]

    # ⑤ 最終找不到 → 明確標示缺失
    return f"[元素 {element_id} 在當前 Wiki dump 中不存在]"

# -------------------------------------------


# ▶︎ 測試三段 evidence
for cid in [
    "Wolfgang_Niedecken_sentence_0",
    "Wolfgang_Niedecken_cell_0_4_1",
    "Wolfgang_Niedecken_sentence_1",
]:
    print("=== ", cid)
    print(fetch_content(cid), "\n")
# Out:
# ===  Wolfgang_Niedecken_sentence_0
# Wolfgang Niedecken (German pronunciation: [[Standard_German|[ˈvɔlfɡaŋ ˈniːdɛkn̩]], Colognian pronunciation: [[Colognian|[ˈvolfjaŋ ˈnidɛkˑən]]; born 30 March 1951) is a German singer, musician, and visual artist.
#
# ===  Wolfgang_Niedecken_cell_0_4_1
# [元素 cell_0_4_1 在當前 Wiki dump 中不存在]
#
# ===  Wolfgang_Niedecken_sentence_1
# He founded the Kölsch speaking rock group [[BAP_(German_band)|BAP]] at the end of the 1970s.

# %%
import asyncio
from tools.sqlite_search_testable import SQLiteSearchTestable

async def test_sqlite_search():
    tool = SQLiteSearchTestable(db_path="C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db")
    await tool.setup()

    page_id = "Wolfgang_Niedecken"
    element_id = "Wolfgang Niedecken_sentence_0"

    result = await tool.search_feverous(page_id, element_id)
    print(f"搜尋結果：{result}")

    await tool.cleanup()

if __name__ == "__main__":
    asyncio.run(test_sqlite_search())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[11], line 17
#      14     await tool.cleanup()
#      16 if __name__ == "__main__":
# ---> 17     asyncio.run(test_sqlite_search())
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\tasks.py:279, in Task.__step(***failed resolving arguments***)
#     277         result = coro.send(None)
#     278     else:
# --> 279         result = coro.throw(exc)
#     280 except StopIteration as exc:
#     281     if self._must_cancel:
#     282         # Task is cancelled right before coro stops.
#
# Cell In[11], line 11, in test_sqlite_search()
#       8 page_id = "Wolfgang_Niedecken"
#       9 element_id = "Wolfgang Niedecken_sentence_0"
# ---> 11 result = await tool.search_feverous(page_id, element_id)
#      12 print(f"搜尋結果：{result}")
#      14 await tool.cleanup()
#
# File ~\Downloads\Test_Agent\Test_5\tools\sqlite_search_testable.py:21, in SQLiteSearchTestable.search_feverous(self, page_id, element_id)
#      16 async def search_feverous(self, page_id: str, element_id: str) -> str:
#      17     query = """
#      18     SELECT value FROM data
#      19     WHERE page_id = ? AND element_id = ?
#      20     """
# ---> 21     async with self.conn.execute(query, (page_id, element_id)) as cursor:
#      22         row = await cursor.fetchone()
#      23         if row:
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\aiosqlite\context.py:41, in Result.__aenter__(self)
#      40 async def __aenter__(self) -> _T:
# ---> 41     self._obj = await self._coro
#      42     return self._obj
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\aiosqlite\core.py:183, in Connection.execute(self, sql, parameters)
#     181 if parameters is None:
#     182     parameters = []
# --> 183 cursor = await self._execute(self._conn.execute, sql, parameters)
#     184 return Cursor(self, cursor)
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\aiosqlite\core.py:122, in Connection._execute(self, fn, *args, **kwargs)
#     118 future = asyncio.get_event_loop().create_future()
#     120 self._tx.put_nowait((future, function))
# --> 122 return await future
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\aiosqlite\core.py:105, in Connection.run(self)
#     103 try:
#     104     LOG.debug("executing %s", function)
# --> 105     result = function()
#     106     LOG.debug("operation %s completed", function)
#     107     future.get_loop().call_soon_threadsafe(set_result, future, result)
#
# OperationalError: no such table: data

# %%
import sqlite3

class SQLiteSearchSimple:
    def __init__(self, db_path):
        self.db_path = db_path
        self.conn = None

    def connect(self):
        self.conn = sqlite3.connect(self.db_path)

    def close(self):
        if self.conn:
            self.conn.close()

    def search_feverous(self, page_id: str, element_id: str) -> str:
        # 解析 element_id
        parts = element_id.split("_")
        if len(parts) < 3:
            raise ValueError(f"Invalid element_id format: {element_id}")

        element_type = parts[1]
        number_id = "_".join(parts[2:])  # 有些是 0_1 這種
        table = ""
        id_col = ""
        text_col = "text"

        if element_type == "sentence":
            table = "sentences"
            id_col = "sentence_id"
        elif element_type == "cell" or element_type == "header_cell":
            table = "cells"
            id_col = "cell_id"
        else:
            raise ValueError(f"Unsupported element type: {element_type}")

        query = f"""
        SELECT {text_col} FROM {table}
        WHERE page_id = ? AND {id_col} = ?
        """

        cursor = self.conn.cursor()
        cursor.execute(query, (page_id, number_id))
        row = cursor.fetchone()
        if row:
            return row[0]
        else:
            return "NOT FOUND"

# 使用方法：
if __name__ == "__main__":
    db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
    tool = SQLiteSearchSimple(db_path)
    tool.connect()

    page_id = "Wolfgang Niedecken"
    element_id = "Wolfgang Niedecken_sentence_0"

    result = tool.search_feverous(page_id, element_id)
    print(f"搜尋結果：{result}")

    tool.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 58
#      55 page_id = "Wolfgang Niedecken"
#      56 element_id = "Wolfgang Niedecken_sentence_0"
# ---> 58 result = tool.search_feverous(page_id, element_id)
#      59 print(f"搜尋結果：{result}")
#      61 tool.close()
#
# Cell In[12], line 42, in SQLiteSearchSimple.search_feverous(self, page_id, element_id)
#      36 query = f"""
#      37 SELECT {text_col} FROM {table}
#      38 WHERE page_id = ? AND {id_col} = ?
#      39 """
#      41 cursor = self.conn.cursor()
# ---> 42 cursor.execute(query, (page_id, number_id))
#      43 row = cursor.fetchone()
#      44 if row:
#
# OperationalError: no such table: sentences

# %%
import sqlite3

def list_tables(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    conn.close()
    return [table[0] for table in tables]

# 測試
db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
tables = list_tables(db_path)
print("資料庫裡有以下表：")
for table in tables:
    print(f"- {table}")
# Out:
# 資料庫裡有以下表：
# - wiki

# %%
import sqlite3

def get_table_schema(db_path, table_name):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()
    conn.close()
    return [(col[1], col[2]) for col in columns]

# 測試
db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
columns = get_table_schema(db_path, "wiki")
print(f"wiki 表的欄位有：")
for col_name, col_type in columns:
    print(f"- {col_name} ({col_type})")
# Out:
# wiki 表的欄位有：
# - id ()
# - data (json)

# %%
import sqlite3
import json

def get_one_example(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT id, data FROM wiki LIMIT 1;")
    row = cursor.fetchone()
    conn.close()
    if row:
        id_value, data_json = row
        parsed_data = json.loads(data_json)
        return id_value, parsed_data
    return None, None

# 測試
db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
id_value, parsed_data = get_one_example(db_path)
print(f"id: {id_value}")
print("data內容的一小部分：")
print(json.dumps(parsed_data, indent=2)[:1000])  # 只印出前1000字避免太長
# Out:
# id: Acuitzeramo, Michoacán
# data內容的一小部分：
# {
#   "order": [
#     "sentence_0",
#     "list_0",
#     "section_0",
#     "sentence_1",
#     "sentence_2",
#     "sentence_3",
#     "sentence_4",
#     "sentence_5",
#     "sentence_6",
#     "sentence_7",
#     "sentence_8",
#     "sentence_9",
#     "sentence_10",
#     "sentence_11",
#     "sentence_12",
#     "sentence_13",
#     "sentence_14",
#     "sentence_15",
#     "sentence_16",
#     "sentence_17",
#     "sentence_18",
#     "sentence_19",
#     "sentence_20",
#     "sentence_21",
#     "sentence_22",
#     "sentence_23",
#     "sentence_24",
#     "sentence_25",
#     "sentence_26",
#     "sentence_27",
#     "sentence_28",
#     "sentence_29",
#     "sentence_30",
#     "sentence_31",
#     "sentence_32",
#     "sentence_33",
#     "sentence_34",
#     "sentence_35",
#     "sentence_36",
#     "sentence_37",
#     "sentence_38",
#     "sentence_39",
#     "sentence_40",
#     "sentence_41",
#     "sentence_42",
#     "sentence_43",
#     "sentence_44",
#     "section_1",
#     "sentence_45",
#     "sentence_46",
#     "sentence_47",
#     "sentence_48",
#     "sentence_49

# %%
import sqlite3
import json

class SQLiteSearchJSON:
    def __init__(self, db_path):
        self.db_path = db_path
        self.conn = None

    def connect(self):
        self.conn = sqlite3.connect(self.db_path)

    def close(self):
        if self.conn:
            self.conn.close()

    def search_feverous(self, page_id: str, element_id: str) -> str:
        query = """
        SELECT data FROM wiki
        WHERE id = ?
        """

        cursor = self.conn.cursor()
        cursor.execute(query, (page_id,))
        row = cursor.fetchone()
        if not row:
            return "NOT FOUND"

        data_json = row[0]
        data = json.loads(data_json)

        # ⭐️ 這裡把 element_id 的 page_id 拿掉
        if not element_id.startswith(page_id):
            return "Invalid element_id for page_id"
        pure_element_id = element_id[len(page_id) + 1:]  # +1 是因為有一個 "_" 需要跳過

        # sentence, cell, header_cell
        if pure_element_id.startswith("sentence"):
            sentences = data.get("sentences", {})
            if pure_element_id in sentences:
                return sentences[pure_element_id].get("text", "NOT FOUND")
        elif pure_element_id.startswith("cell"):
            cells = data.get("cells", {})
            if pure_element_id in cells:
                return cells[pure_element_id].get("text", "NOT FOUND")
        elif pure_element_id.startswith("header_cell"):
            headers = data.get("headers", {})
            if pure_element_id in headers:
                return headers[pure_element_id].get("text", "NOT FOUND")

        return "NOT FOUND"

# 使用方法
if __name__ == "__main__":
    db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
    tool = SQLiteSearchJSON(db_path)
    tool.connect()

    page_id = "Acuitzeramo, Michoacán"
    element_id = "Acuitzeramo, Michoacán_sentence_0"

    result = tool.search_feverous(page_id, element_id)
    print(f"搜尋結果：{result}")

    tool.close()
# Out:
# 搜尋結果：NOT FOUND

# %%
import sqlite3

def check_page_id(db_path, page_id):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT 1 FROM wiki WHERE id = ?", (page_id,))
    result = cursor.fetchone()
    conn.close()
    return result is not None

# 測試
db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
page_id = "Acuitzeramo, Michoacán"
print(check_page_id(db_path, page_id))  # 會印 True or False
# Out:
# True

# %%
import sqlite3
import json

class SQLiteSearchJSON:
    def __init__(self, db_path):
        self.db_path = db_path
        self.conn = None

    def connect(self):
        self.conn = sqlite3.connect(self.db_path)

    def close(self):
        if self.conn:
            self.conn.close()

    def search_feverous(self, page_id: str, element_id: str) -> str:
        print(f"🔍 正在查 page_id: {page_id}")
        query = """
        SELECT data FROM wiki
        WHERE id = ?
        """

        cursor = self.conn.cursor()
        cursor.execute(query, (page_id,))
        row = cursor.fetchone()
        if not row:
            print(f"⚠️ 找不到 page_id {page_id}！")
            return "NOT FOUND"

        data_json = row[0]
        data = json.loads(data_json)

        if not element_id.startswith(page_id):
            print(f"⚠️ element_id {element_id} 和 page_id {page_id} 不符！")
            return "Invalid element_id for page_id"

        pure_element_id = element_id[len(page_id) + 1:]
        print(f"🔍 查詢元素: {pure_element_id}")

        if pure_element_id.startswith("sentence"):
            sentences = data.get("sentences", {})
            print(f"✅ sentences 有 {len(sentences)} 條資料")
            if pure_element_id in sentences:
                print(f"✅ 找到句子 {pure_element_id}")
                return sentences[pure_element_id].get("text", "NOT FOUND")
            else:
                print(f"⚠️ 找不到句子 {pure_element_id}")
        elif pure_element_id.startswith("cell"):
            cells = data.get("cells", {})
            if pure_element_id in cells:
                return cells[pure_element_id].get("text", "NOT FOUND")
        elif pure_element_id.startswith("header_cell"):
            headers = data.get("headers", {})
            if pure_element_id in headers:
                return headers[pure_element_id].get("text", "NOT FOUND")

        return "NOT FOUND"

# 使用方法
if __name__ == "__main__":
    db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
    tool = SQLiteSearchJSON(db_path)
    tool.connect()

    page_id = "Acuitzeramo, Michoacán"
    element_id = "Acuitzeramo, Michoacán_sentence_0"

    result = tool.search_feverous(page_id, element_id)
    print(f"搜尋結果：{result}")

    tool.close()
# Out:
# 🔍 正在查 page_id: Acuitzeramo, Michoacán
# 🔍 查詢元素: sentence_0
# ✅ sentences 有 0 條資料
# ⚠️ 找不到句子 sentence_0
# 搜尋結果：NOT FOUND

# %%
import sqlite3
import json

def get_data(db_path, page_id):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT data FROM wiki WHERE id = ?", (page_id,))
    row = cursor.fetchone()
    conn.close()
    if row:
        data = json.loads(row[0])
        return data
    return None

# 測試
db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
page_id = "Acuitzeramo, Michoacán"
data = get_data(db_path, page_id)
print(json.dumps(data, indent=2)[:2000])  # 印出前2000字，避免太長
# Out:
# {
#   "order": [
#     "sentence_0",
#     "list_0",
#     "section_0",
#     "sentence_1",
#     "sentence_2",
#     "sentence_3",
#     "sentence_4",
#     "sentence_5",
#     "sentence_6",
#     "sentence_7",
#     "sentence_8",
#     "sentence_9",
#     "sentence_10",
#     "sentence_11",
#     "sentence_12",
#     "sentence_13",
#     "sentence_14",
#     "sentence_15",
#     "sentence_16",
#     "sentence_17",
#     "sentence_18",
#     "sentence_19",
#     "sentence_20",
#     "sentence_21",
#     "sentence_22",
#     "sentence_23",
#     "sentence_24",
#     "sentence_25",
#     "sentence_26",
#     "sentence_27",
#     "sentence_28",
#     "sentence_29",
#     "sentence_30",
#     "sentence_31",
#     "sentence_32",
#     "sentence_33",
#     "sentence_34",
#     "sentence_35",
#     "sentence_36",
#     "sentence_37",
#     "sentence_38",
#     "sentence_39",
#     "sentence_40",
#     "sentence_41",
#     "sentence_42",
#     "sentence_43",
#     "sentence_44",
#     "section_1",
#     "sentence_45",
#     "sentence_46",
#     "sentence_47",
#     "sentence_48",
#     "sentence_49",
#     "sentence_50",
#     "sentence_51",
#     "sentence_52",
#     "sentence_53",
#     "sentence_54"
#   ],
#   "title": "Acuitzeramo, Michoaca\u0301n",
#   "sentence_0": "Acuitzeramo (Spanish pronunciation: [[Spanish|[akwitse\u02c8\u027eamo]]) is a small town located in the municipality of Tlazazalca in the [[Mexico|Mexican]] [[Mexican_state|state]] of [[Michoaca\u0301n|Michoaca\u0301n]].",
#   "list_0": {
#     "list": [
#       {
#         "id": "item_0_0",
#         "value": "(in Spanish)",
#         "level": 0
#       },
#       {
#         "id": "item_0_1",
#         "value": "(in Spanish) at PueblosAmerica.com",
#         "level": 0
#       }
#     ],
#     "type": "unordered_list"
#   },
#   "section_0": {
#     "value": "History",
#     "level": 2
#   },
#   "sentence_1": "Acultzeramo, Mpio.",
#   "sentence_2": "Tlazazalca.",
#   "sentence_3": "The inhabitants of the towns of Villa Mendoza, also known as old houses, and Acuitzeramo now struggle to get rid of these ties that have prevented progress and achieve a better standard of

# %%
import sqlite3
import json

class SQLiteSearchJSON:
    def __init__(self, db_path):
        self.db_path = db_path
        self.conn = None

    def connect(self):
        self.conn = sqlite3.connect(self.db_path)

    def close(self):
        if self.conn:
            self.conn.close()

    def search_feverous(self, page_id: str, element_id: str) -> str:
        print(f"🔍 正在查 page_id: {page_id}")
        query = """
        SELECT data FROM wiki
        WHERE id = ?
        """

        cursor = self.conn.cursor()
        cursor.execute(query, (page_id,))
        row = cursor.fetchone()
        if not row:
            print(f"⚠️ 找不到 page_id {page_id}！")
            return "NOT FOUND"

        data_json = row[0]
        data = json.loads(data_json)

        if not element_id.startswith(page_id):
            print(f"⚠️ element_id {element_id} 和 page_id {page_id} 不符！")
            return "Invalid element_id for page_id"

        pure_element_id = element_id[len(page_id) + 1:]
        print(f"🔍 查詢元素: {pure_element_id}")

        # 🆕 更新：直接找 data 的 key
        value = data.get(pure_element_id)
        if value:
            if isinstance(value, dict):
                return value.get("text", str(value))  # 如果是 dict 優先拿 text 欄位
            else:
                return value  # 直接是句子字串
        else:
            return "NOT FOUND"

# 使用方法
if __name__ == "__main__":
    db_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"
    tool = SQLiteSearchJSON(db_path)
    tool.connect()

    page_id = "Acuitzeramo, Michoacán"
    element_id = "Acuitzeramo, Michoacán_sentence_0"

    result = tool.search_feverous(page_id, element_id)
    print(f"搜尋結果：{result}")

    tool.close()
# Out:
# 🔍 正在查 page_id: Acuitzeramo, Michoacán
# 🔍 查詢元素: sentence_0
# 搜尋結果：Acuitzeramo (Spanish pronunciation: [[Spanish|[akwitseˈɾamo]]) is a small town located in the municipality of Tlazazalca in the [[Mexico|Mexican]] [[Mexican_state|state]] of [[Michoacán|Michoacán]].

# %%
import asyncio
from tools.sqlite_search import SQLiteSearch

async def test_sqlite_tool():
    # 建立一個假的 app 和 kani
    class FakeApp:
        pass

    class FakeKani:
        pass

    # 用假的 app 和 kani 建立 tool
    tool = SQLiteSearch(app=FakeApp(), kani=FakeKani(), db_path="C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db")
    await tool.setup()

    # 測試查詢
    page_id = "Acuitzeramo, Michoacán"
    element_id = "Acuitzeramo, Michoacán_sentence_0"

    result = await tool.search_feverous(page_id, element_id)
    print(f"搜尋結果：{result}")

    await tool.cleanup()

if __name__ == "__main__":
    asyncio.run(test_sqlite_tool())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[21], line 26
#      23     await tool.cleanup()
#      25 if __name__ == "__main__":
# ---> 26     asyncio.run(test_sqlite_tool())
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\tasks.py:279, in Task.__step(***failed resolving arguments***)
#     277         result = coro.send(None)
#     278     else:
# --> 279         result = coro.throw(exc)
#     280 except StopIteration as exc:
#     281     if self._must_cancel:
#     282         # Task is cancelled right before coro stops.
#
# Cell In[21], line 20, in test_sqlite_tool()
#      17 page_id = "Acuitzeramo, Michoacán"
#      18 element_id = "Acuitzeramo, Michoacán_sentence_0"
# ---> 20 result = await tool.search_feverous(page_id, element_id)
#      21 print(f"搜尋結果：{result}")
#      23 await tool.cleanup()
#
# File ~\Downloads\Test_Agent\Test_5\tools\sqlite_search.py:28, in SQLiteSearch.search_feverous(self, page_id, element_id)
#      18 @ai_function(desc="Search for content in the Feverous database by page_id and element_id.")
#      19 async def search_feverous(
#      20     self,
#      21     page_id: str,
#      22     element_id: str
#      23 ) -> str:
#      24     query = """
#      25     SELECT value FROM data
#      26     WHERE page_id = ? AND element_id = ?
#      27     """
# ---> 28     async with self.conn.execute(query, (page_id, element_id)) as cursor:
#      29         row = await cursor.fetchone()
#      30         if row:
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\aiosqlite\context.py:41, in Result.__aenter__(self)
#      40 async def __aenter__(self) -> _T:
# ---> 41     self._obj = await self._coro
#      42     return self._obj
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\aiosqlite\core.py:183, in Connection.execute(self, sql, parameters)
#     181 if parameters is None:
#     182     parameters = []
# --> 183 cursor = await self._execute(self._conn.execute, sql, parameters)
#     184 return Cursor(self, cursor)
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\aiosqlite\core.py:122, in Connection._execute(self, fn, *args, **kwargs)
#     118 future = asyncio.get_event_loop().create_future()
#     120 self._tx.put_nowait((future, function))
# --> 122 return await future
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~\anaconda3\envs\crew_env\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\anaconda3\envs\crew_env\Lib\site-packages\aiosqlite\core.py:105, in Connection.run(self)
#     103 try:
#     104     LOG.debug("executing %s", function)
# --> 105     result = function()
#     106     LOG.debug("operation %s completed", function)
#     107     future.get_loop().call_soon_threadsafe(set_result, future, result)
#
# OperationalError: no such table: data

# %%
import asyncio
import json
import os
from app import AutoAgentSystem
from tools.sqlite_search import SQLiteSearch

async def batch_test(dataset_path, output_path):
    # 初始化系統
    app = AutoAgentSystem(
        tool_configs={
            SQLiteSearch: {
                "always_include": True,
                "kwargs": {
                    "db_path": "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_wikiv1.db"  # 你的DB路徑
                }
            }
        },
        root_has_tools=True
    )
    kani = await app.ensure_init()

    # 讀取你的 JSONL dataset
    with open(dataset_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    results = []

    for line in lines:
        sample = json.loads(line)
        claim_id = sample["id"]
        claim_text = sample["claim"]
        evidence = sample.get("evidence", {})
        label = sample.get("label", "NOT AVAILABLE")

        # 如果 evidence 不存在，跳過
        if not evidence:
            results.append({
                "id": claim_id,
                "claim": claim_text,
                "result": "No evidence provided",
                "label": label
            })
            continue

        page_elements = evidence.get("content", [])
        claim_results = []

        # 查詢 evidence 中每一個 element_id
        for element_id in page_elements:
            context = evidence.get("context", {}).get(element_id, [])
            if not context:
                claim_results.append(f"Element {element_id} no context")
                continue

            # context 第一個應該是 page_id
            page_id = context[0]

            # 用 tool 查詢
            tool = kani.get_tool(SQLiteSearch)
            result = await tool.search_feverous(page_id, element_id)
            claim_results.append({
                "page_id": page_id,
                "element_id": element_id,
                "result": result
            })

        results.append({
            "id": claim_id,
            "claim": claim_text,
            "evidences": claim_results,
            "label": label
        })

    # 把結果存檔
    with open(output_path, 'w', encoding='utf-8') as f_out:
        json.dump(results, f_out, indent=2, ensure_ascii=False)

    print(f"✅ 測試完成，結果已存到 {output_path}")

    await app.close()

if __name__ == "__main__":
    dataset_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/feverous_dev.jsonl"  # 你的 dataset 路徑
    output_path = "C:/Users/USER/Downloads/Test_Agent/Test_5/Dataset/test_results.json"
    asyncio.run(batch_test(dataset_path, output_path))
# Out:
# 請輸入你的指令:  請幫我查詢 page_id 是 "Acuitzeramo, Michoacán"，element_id 是 "Acuitzeramo, Michoacán_sentence_0" 的內容。
# AI:為了完成這項任務，我將會委派一位專家代理人來查找指定的內容。請稍等片刻，我將分配這項任務。
#
# [✅ 任務指派] Agent: alpha
# 📄 被指派的任務：
# Please search for the content associated with page_id 'Acuitzeramo, Michoacán' and element_id 'Acuitzeramo, Michoacán_sentence_0'. Retrieve the specific content from the database or any available resources.
# ----------------------------------------
#
# AI:'alpha' is helping you with this request.
# AI:
# Task exception was never retrieved
# future: <Task finished name='Task-150' coro=<Connection.run() done, defined at C:\Users\USER\anaconda3\envs\crew_env\Lib\site-packages\playwright\_impl\_connection.py:272> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\asyncio\tasks.py", line 277, in __step
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\site-packages\playwright\_impl\_connection.py", line 279, in run
#     await self._transport.connect()
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\asyncio\subprocess.py", line 223, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\asyncio\base_events.py", line 1708, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\asyncio\base_events.py", line 503, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# Playwright.goto failed for https://en.wikipedia.org/wiki/Acuitzeramo,_Michoacán
# Traceback (most recent call last):
#   File "C:\Users\USER\Downloads\Test_Agent\Test_5\tools\browsing\impl.py", line 240, in html_content
#     page = await self.get_page()
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\Downloads\Test_Agent\Test_5\tools\browsing\impl.py", line 108, in get_page
#     context = await self.get_browser()
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\Downloads\Test_Agent\Test_5\tools\browsing\impl.py", line 95, in get_browser
#     Browsing.playwright = await async_playwright().start()
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\site-packages\playwright\async_api\_context_manager.py", line 51, in start
#     return await self.__aenter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\site-packages\playwright\async_api\_context_manager.py", line 46, in __aenter__
#     playwright = AsyncPlaywright(next(iter(done)).result())
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\asyncio\futures.py", line 203, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\asyncio\subprocess.py", line 223, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\asyncio\base_events.py", line 1708, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\envs\crew_env\Lib\asyncio\base_events.py", line 503, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# AI:alpha:📌 Acuitzeramo, Michoacán - Wikipedia
# 🔗 https://en.wikipedia.org/wiki/Acuitzeramo,_Michoacán
# 📝 Acuitzeramo (Spanish pronunciation: [akwitseˈɾamo]) is a small town located in the municipality of Tlazazalca in the Mexican state of Michoacán. External links [ edit ]
#
# 📌 Acuitzeramo, Michoacán
# 🔗 http://acuitzeramo.com/
# 📝 Acuitzeramo, Michoacán situado al noroeste de Purépero . es jefatura de Tenencia del municipio de Tlazazalca actualmente tiene dos vías de acceso: una que parte de Purépero, pasando por el Salto, Villa Mendoza, con una extensión de aproximadamente 10 Km.; la otra que va de Purépero. Tlazazalca, La Yerbabuena, San. Isidro y Acuitzeramo ...
#
# 📌 Acutzeramo Michoacan Mrxico - YouTube
# 🔗 https://www.youtube.com/watch?v=HYh2g6sUrnM
# 📝 Take a virtual tour of Acutzeramo in Michoacan, Mexico! Explore the vibrant culture, delicious cuisine, and stunning scenery of this beautiful Mexican town. ...❌ Failed to load the page via Playwright: It seems I couldn't directly access the Wikipedia page for "Acuitzeramo, Michoacán." However, based on the search results, here is some information about Acuitzeramo, Michoacán:
#
# - Acuitzeramo is a small town located in the municipality of Tlazazalca in the Mexican state of Michoacán.
# - It is situated to the northwest of Purépero and serves as the head of Tenencia (local administrative unit) for the municipality of Tlazazalca.
# - The town has two main access routes: one starts from Purépero, passing through El Salto and Villa Mendoza, extending approximately 10 km; the other route connects from Purépero through Tlazazalca, La Yerbabuena, San Isidro, and Acuitzeramo.
#
# If you need more detailed or specific information, such as the exact content of a particular sentence, you may want to visit the page directly or specify another method for retrieving the data.
# AI:我已經找到一些關於 Acuitzeramo, Michoacán 的一般資訊：
#
# - Acuitzeramo 是位於墨西哥 Michoacán 州 Tlazazalca 市的一個小鎮。
# - 它位於 Purépero 的西北部，並作為 Tlazazalca 市的地方行政單位（Tenencia）的管理中心。
# - 該鎮有兩條主要的進入路線：一條從 Purépero 出發，經過 El Salto 和 Villa Mendoza，延伸約 10 公里；另一條路線從 Purépero 經過 Tlazazalca、La Yerbabuena、San Isidro 到達 Acuitzeramo。
#
# 不過，指定的 element_id "Acuitzeramo, Michoacán_sentence_0" 的具體內容無法直接取得。如果您需要更詳細或特定的內容，建議直接訪問相關頁面或使用其他方法來獲取資料。
# 請輸入你的指令:  exit

# %%
import os
import json

class WikipediaRetriever:
    def __init__(self, wiki_dir):
        self.wiki_dir = wiki_dir
        self.page_index = {}

    def build_index(self):
        print("Building index... (only indexing page titles and file positions)")
        # 先建立一個 page_name -> 檔案路徑的 mapping
        for filename in os.listdir(self.wiki_dir):
            if filename.endswith('.jsonl'):
                file_path = os.path.join(self.wiki_dir, filename)
                with open(file_path, 'r', encoding='utf-8') as f:
                    for line in f:
                        data = json.loads(line)
                        page_id = data['id']
                        self.page_index[page_id] = file_path
        print(f"Index built: {len(self.page_index)} pages indexed.")

    def get_page(self, page_id):
        if page_id not in self.page_index:
            print(f"Page {page_id} not found in index.")
            return None
        file_path = self.page_index[page_id]
        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                data = json.loads(line)
                if data['id'] == page_id:
                    return data
        print(f"Page {page_id} not found in file {file_path}.")
        return None

    def get_sentence(self, page_id, sentence_id):
        page = self.get_page(page_id)
        if page is None:
            return None
        try:
            return page['text'][sentence_id]
        except IndexError:
            print(f"Sentence {sentence_id} not found in page {page_id}.")
            return None

# 使用方式
wiki_dir = r"C:\Users\USER\Downloads\Test_Agent\Test_5\Dataset\FEVER\wiki-pages"
retriever = WikipediaRetriever(wiki_dir)
retriever.build_index()

# 測試：找一個 page 和 sentence
page_id = "Oliver_Reed"
sentence_id = 0
sentence = retriever.get_sentence(page_id, sentence_id)
print("Retrieved sentence:", sentence)
# Out:
# Building index... (only indexing page titles and file positions)
# Index built: 5416537 pages indexed.
# Retrieved sentence: R
